# %%
with open("Untitled form (Responses) (1).csv",'r') as f:
    r=f.readline()
    print(r)
# Out:
# Timestamp,Your Name ,Your Course Name ,Select Gender,Hostel type,Water Facility in Hostel,WIFI Facility,Transportation Facility,Adjustment issue with Room-mates,Your regular food preference,Coping-up with Christ Rules & Regulation,Are you willing to shift to Private Accommodation?,How do you rate your experience of staying in Christ Hostel out of 5 ?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Untitled form (Responses) (1).csv")       #reading the csv file
data
# Out:
#                Timestamp             Your Name   \
# 0                    NaN                    NaN
# 1                    NaN                    NaN
# 2     10-9-2023 15:11:01     Sampadha Varanasi
# 3     10-9-2023 15:19:54                Indu pv
# 4     10-9-2023 15:24:04        Sudiksha sharma
# ..                   ...                    ...
# 184  10-20-2023 16:19:48      Shivam  Chaudhary
# 185  10-20-2023 16:25:44  Suvadeep Chakraborty
# 186  10-20-2023 16:26:10    Rhea Eleanor Rhine
# 187                  NaN                    NaN
# 188                  NaN                    NaN
#
#                   Your Course Name  Select Gender         Hostel type  \
# 0                               NaN           NaN                 NaN
# 1                               NaN           NaN                 NaN
# 2         MSc Economics & Analytics        Female  Christ Celebration
# 3         MSc Economics & Analytics        Female    Christ Residence
# ...

# %%
data.drop(columns=data.columns[0], inplace=True)      #removing the unnecessary coloumns
data
# Out:
#                 Your Name                Your Course Name  Select Gender  \
# 0                      NaN                             NaN           NaN
# 1                      NaN                             NaN           NaN
# 2       Sampadha Varanasi        MSc Economics & Analytics        Female
# 3                  Indu pv       MSc Economics & Analytics        Female
# 4          Sudiksha sharma       MSc Economics & Analytics        Female
# ..                     ...                             ...           ...
# 184      Shivam  Chaudhary                             BBA          Male
# 185  Suvadeep Chakraborty   MSc Global Finance & Analytics          Male
# 186    Rhea Eleanor Rhine                           BA LLB        Female
# 187                    NaN                             NaN           NaN
# 188                    NaN                             NaN           NaN
#
#             Hostel type Water Facility in Hostel WIFI Facility  \
# ...

# %%
data.drop([0,1,187,188],axis=0,inplace=True)          #removing the unnecessary rows
data
# Out:
#                Timestamp             Your Name   \
# 2     10-9-2023 15:11:01     Sampadha Varanasi
# 3     10-9-2023 15:19:54                Indu pv
# 4     10-9-2023 15:24:04        Sudiksha sharma
# 5     10-9-2023 17:01:19  Suvadeep Chakraborty
# 6     10-9-2023 17:18:39        Akshita Nawani
# ..                   ...                    ...
# 182  10-19-2023 16:14:02                   Ujan
# 183  10-19-2023 17:46:07                 Aishik
# 184  10-20-2023 16:19:48      Shivam  Chaudhary
# 185  10-20-2023 16:25:44  Suvadeep Chakraborty
# 186  10-20-2023 16:26:10    Rhea Eleanor Rhine
#
#                   Your Course Name  Select Gender         Hostel type  \
# 2         MSc Economics & Analytics        Female  Christ Celebration
# 3         MSc Economics & Analytics        Female    Christ Residence
# 4         MSc Economics & Analytics        Female    Christ Residence
# 5    MSc Global Finance & Analytics          Male    Christ Residence
# ...

# %%
data.head()                #printing the first few data
# Out:
#            Your Name           Your Course Name  Select Gender  \
# 0                 NaN                        NaN           NaN
# 1                 NaN                        NaN           NaN
# 2  Sampadha Varanasi   MSc Economics & Analytics        Female
# 3             Indu pv  MSc Economics & Analytics        Female
# 4     Sudiksha sharma  MSc Economics & Analytics        Female
#
#           Hostel type Water Facility in Hostel WIFI Facility  \
# 0                 NaN                      NaN           NaN
# 1                 NaN                      NaN           NaN
# 2  Christ Celebration                     Good       Average
# 3    Christ Residence                      Bad       Average
# 4    Christ Residence                  Average           Bad
#
#   Transportation Facility Adjustment issue with Room-mates  \
# 0                     NaN                              NaN
# 1                     NaN                              NaN
# ...

# %%
data.tail()                 #printing the last few data
# Out:
#                 Your Name                Your Course Name  Select Gender  \
# 184      Shivam  Chaudhary                             BBA          Male
# 185  Suvadeep Chakraborty   MSc Global Finance & Analytics          Male
# 186    Rhea Eleanor Rhine                           BA LLB        Female
# 187                    NaN                             NaN           NaN
# 188                    NaN                             NaN           NaN
#
#           Hostel type Water Facility in Hostel WIFI Facility  \
# 184             Villa                      Bad           Bad
# 185  Christ Residence                  Average       Average
# 186  Christ Residence                  Average          Good
# 187               NaN                      NaN           NaN
# 188               NaN                      NaN           NaN
#
#         Transportation Facility Adjustment issue with Room-mates  \
# 184  Any Private Transportation                        I'm happy
# ...

# %%
df=pd.DataFrame(data)

# %%
df[data.columns]             #printing the coloumns
# Out:
#                 Your Name                Your Course Name  Select Gender  \
# 0                      NaN                             NaN           NaN
# 1                      NaN                             NaN           NaN
# 2       Sampadha Varanasi        MSc Economics & Analytics        Female
# 3                  Indu pv       MSc Economics & Analytics        Female
# 4          Sudiksha sharma       MSc Economics & Analytics        Female
# ..                     ...                             ...           ...
# 184      Shivam  Chaudhary                             BBA          Male
# 185  Suvadeep Chakraborty   MSc Global Finance & Analytics          Male
# 186    Rhea Eleanor Rhine                           BA LLB        Female
# 187                    NaN                             NaN           NaN
# 188                    NaN                             NaN           NaN
#
#             Hostel type Water Facility in Hostel WIFI Facility  \
# ...

# %% [markdown]
# ## Checking for wrong entries like symbols -,?,#,*,etc.

# %%
for col in data.columns:
    print('{} : {}'.format(col,df[col].unique()))
# Out:
# Your Name  : [nan 'Sampadha Varanasi ' 'Indu pv' 'Sudiksha sharma'
#  'Suvadeep Chakraborty ' 'Akshita Nawani ' 'Manika Sehgal ' 'Karthik'
#  'SWASTIK ROY' 'Siddhartha Sinha ' 'Kingsuk' 'Tanisha Agarwal ' 'Tanu'
#  'Ardra K S' 'Trikalagga Saha ' 'Stuty Das' 'CVSS ANIRUDH' 'Sandeep Kumar'
#  'R Lalrinmawii' 'Riya PC' 'Hitanshi Gupta' 'Jaise george '
#  'Vikash Shakya ' 'Vedanta Nanda' 'Jofin' 'Alen Jin Shibu '
#  'Debolina Chatterjee ' 'Souradeepta Mazumder '
#  'Mathews Mathew Plathottam ' 'Nilanjana Dey' 'Aadith Joseph Mathew '
#  'Gokul Manoj ' 'Prajwal Singh' 'Kirti Sharma ' 'Arshika Saraswat'
#  'Tushar ' 'Arghya Basu ' 'Muskan Jain' 'Raju pille '
#  'John George Thattil ' 'Anushya Francisca ' 'Devika S Vinod'
#  'Adharsh jaison' 'Tanuja Gupta ' 'Smaira ' 'Shubhalaxmi Sagare '
#  'Mehuli Dutta' 'Shruti Mishra' 'Avinash ' 'Samiksha Gupta '
#  'Sankar Murugan ' 'sb' 'Souvik Chowdhury ' 'Sidharth' 'sarnalika paul'
#  'sarnalika.paul@msds.christuniversity.in ' 'Ritu Kumari Shaw '
# ...

# %% [markdown]
# # CHECKING IF THERE ARE ANY MISSING VALUES

# %%
sns.heatmap(data.isnull(),cbar=False,cmap='viridis')                # USING HEAT MAP
# Out:
# <Axes: >

# %% [markdown]
# WE CAN SEE THAT THERE ARE NO MISSING VALUES PRESENT IN THE DATASET

# %% [markdown]
# -----------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# check for duplication

# %%
data=data.drop_duplicates(keep='last')
data
# Out:
#                 Your Name                Your Course Name  Select Gender  \
# 2       Sampadha Varanasi        MSc Economics & Analytics        Female
# 3                  Indu pv       MSc Economics & Analytics        Female
# 4          Sudiksha sharma       MSc Economics & Analytics        Female
# 5    Suvadeep Chakraborty   MSc Global Finance & Analytics          Male
# 6          Akshita Nawani   MSc Global Finance & Analytics        Female
# ..                     ...                             ...           ...
# 183                 Aishik                             BBA          Male
# 184      Shivam  Chaudhary                             BBA          Male
# 185  Suvadeep Chakraborty   MSc Global Finance & Analytics          Male
# 186    Rhea Eleanor Rhine                           BA LLB        Female
# 188                    NaN                             NaN           NaN
#
#             Hostel type Water Facility in Hostel     WIFI Facility  \
# ...

# %%
data.nunique()                                    # UNIQUE ITEMS REPRESENTATION
# Out:
# Your Name                                                                 164
# Your Course Name                                                           10
# Select Gender                                                               2
# Hostel type                                                                 3
# Water Facility in Hostel                                                    3
# WIFI Facility                                                               4
# Transportation Facility                                                     3
# Adjustment issue with Room-mates                                            3
# Your regular food preference                                                3
# Coping-up with Christ Rules & Regulation                                    2
# Are you willing to shift to Private Accommodation?                          2
# How do you rate your experience of staying in Christ Hostel out of 5 ?      5
# dtype: int64

# %%
data.isnull().sum()                                  #CHECKING WETHER ANY NULL VALUE IS PRESENT OR NOT
# Out:
# Your Name                                                                 1
# Your Course Name                                                          1
# Select Gender                                                             1
# Hostel type                                                               1
# Water Facility in Hostel                                                  1
# WIFI Facility                                                             1
# Transportation Facility                                                   1
# Adjustment issue with Room-mates                                          1
# Your regular food preference                                              1
# Coping-up with Christ Rules & Regulation                                  1
# Are you willing to shift to Private Accommodation?                        1
# How do you rate your experience of staying in Christ Hostel out of 5 ?    1
# dtype: int64

# %%
null_perc=(100*(data.isnull().sum()/len(data.index)))          
null_perc[null_perc>0]
# Out:
# Your Name                                                                 0.543478
# Your Course Name                                                          0.543478
# Select Gender                                                             0.543478
# Hostel type                                                               0.543478
# Water Facility in Hostel                                                  0.543478
# WIFI Facility                                                             0.543478
# Transportation Facility                                                   0.543478
# Adjustment issue with Room-mates                                          0.543478
# Your regular food preference                                              0.543478
# Coping-up with Christ Rules & Regulation                                  0.543478
# Are you willing to shift to Private Accommodation?                        0.543478
# ...

# %%
print('Original DataFrame:')
print(df)
print('\n')

# Default configuration drops rows having at least 1 missing value
print('DataFrame after dropping the rows having missing values:')
print(df.dropna())
# Out:
# Original DataFrame:
#                 Your Name                Your Course Name  Select Gender  \
# 0                      NaN                             NaN           NaN
# 1                      NaN                             NaN           NaN
# 2       Sampadha Varanasi        MSc Economics & Analytics        Female
# 3                  Indu pv       MSc Economics & Analytics        Female
# 4          Sudiksha sharma       MSc Economics & Analytics        Female
# ..                     ...                             ...           ...
# 184      Shivam  Chaudhary                             BBA          Male
# 185  Suvadeep Chakraborty   MSc Global Finance & Analytics          Male
# 186    Rhea Eleanor Rhine                           BA LLB        Female
# 187                    NaN                             NaN           NaN
# 188                    NaN                             NaN           NaN
#
#             Hostel type Water Facility in Hostel WIFI Facility  \
# ...

# %% [markdown]
# NUMERICAL AND CATEGORICAL VARIABLES :

# %%
cat_cols=data.select_dtypes(include=['object']).columns
num_cols = data.select_dtypes(include=np.number).columns.tolist()
print("Categorical Variables:")
print(cat_cols)
print("Numerical Variables:")
print(num_cols)
# Out:
# Categorical Variables:
# Index(['Your Name ', 'Your Course Name ', 'Select Gender', 'Hostel type',
#        'Water Facility in Hostel', 'WIFI Facility', 'Transportation Facility',
#        'Adjustment issue with Room-mates', 'Your regular food preference',
#        'Coping-up with Christ Rules & Regulation',
#        'Are you willing to shift to Private Accommodation?'],
#       dtype='object')
# Numerical Variables:
# ['How do you rate your experience of staying in Christ Hostel out of 5 ?']

# %% [markdown]
# DESCRIBE THE DATA

# %%
data.describe(include='all').T
# Out:
#                                                     count unique  \
# Your Name                                             183    164
# Your Course Name                                      183     10
# Select Gender                                         183      2
# Hostel type                                           183      3
# Water Facility in Hostel                              183      3
# WIFI Facility                                         183      4
# Transportation Facility                               183      3
# Adjustment issue with Room-mates                      183      3
# Your regular food preference                          183      3
# Coping-up with Christ Rules & Regulation              183      2
# Are you willing to shift to Private Accommodation?    183      2
# How do you rate your experience of staying in C...  183.0    NaN
#
#                                                                              top  \
# ...

# %%
data.dropna(inplace=True)
print(data.isnull().sum())
# Out:
# Your Name                                                                 0
# Your Course Name                                                          0
# Select Gender                                                             0
# Hostel type                                                               0
# Water Facility in Hostel                                                  0
# WIFI Facility                                                             0
# Transportation Facility                                                   0
# Adjustment issue with Room-mates                                          0
# Your regular food preference                                              0
# Coping-up with Christ Rules & Regulation                                  0
# Are you willing to shift to Private Accommodation?                        0
# How do you rate your experience of staying in Christ Hostel out of 5 ?    0
# dtype: int64
# ...

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# DETERMINING THE CORRELATION BETWEEN SHIFITNG TO PRIVATE AND DIFFERENT ATTRIBUTES

# %% [markdown]
# The primary use of the chi-square test is to examine whether two variables are independent or not.
#
# The chi-square test begins with a handful of assumptions, a pair of hypotheses, a sampling distribution and an alpha level and ends with a conclusion obtained via comparison of an obtained statistic with a critical statistic. The assumptions associated with the chi-square test are fairly straightforward: the data at hand must have been randomly selected (to minimize potential biases) and the variables in question must be nominal or ordinal
#
# The null hypothesis states that there is no relationship between the two variables, while the research hypothesis states that there is a relationship between the two variables. The test statistic follows a chi-square distribution, and the conclusion depends on whether or not our obtained statistic is greater that the critical statistic at our chosen alpha level.

# %% [markdown]
# --> Here The specific hypotheses are:
#
# --> H0: There is a relationship between two variables
# --> H1: There is no relationship between two variables.
#
#
# --> The p-value approach to hypothesis testing uses the calculated probability to determine whether there is evidence to reject the null  hypothesis.
# --> The p-value is the probability of obtaining results at least as extreme as the observed results of a statistical hypothesis test, assuming that the null hypothesis is correct.
#
#
# --> P = p - value
#
#
# --> P denotes the probability. The different p-values indicate different types of hypothesis interpretations.
#
# --> P <= 0.05 (H0 is accepted)
# --> P>= 0.05 (H1 is accepted)

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Checking relationship between WIFI FACILITY  and SHIFTING TO PRIVATES

# %% [markdown]
# --> Here The specific hypotheses are:
#
# --> H0: There is a relationship between WIFI FACILITY  and SHIFTING TO PRIVATES
# --> H1: There is no relationship between WIFI FACILITY  and SHIFTING TO PRIVATES
#
#
#
# --> P denotes the probability. The different p-values indicate different types of hypothesis interpretations.
#
# --> P <= 0.05 (H0 is accepted)
# --> P>= 0.05 (H1 is accepted)

# %%
! pip install scipy
# Out:
# ...
#                                               0.0/44.1 MB ? eta -:--:--
#                                               0.0/44.1 MB ? eta -:--:--
#                                              0.0/44.1 MB 445.2 kB/s eta 0:01:39
#                                              0.0/44.1 MB 245.8 kB/s eta 0:03:00
#                                              0.1/44.1 MB 328.2 kB/s eta 0:02:15
#                                              0.1/44.1 MB 353.1 kB/s eta 0:02:05
#                                              0.1/44.1 MB 409.6 kB/s eta 0:01:48
#                                              0.1/44.1 MB 426.7 kB/s eta 0:01:44
#                                              0.2/44.1 MB 477.7 kB/s eta 0:01:32
#                                              0.2/44.1 MB 498.9 kB/s eta 0:01:28
#                                              0.3/44.1 MB 609.2 kB/s eta 0:01:12
#                                              0.3/44.1 MB 613.6 kB/s eta 0:01:12
# ...

# %%
import scipy

# %%
# Cross tabulation between WIFI FACILTY and SHIFTING TO PRIVATE
CrosstabResult=pd.crosstab(index=data['WIFI Facility'],columns=data['Are you willing to shift to Private Accommodation?'])
print(CrosstabResult)

from scipy.stats import chi2_contingency
 
# Performing Chi-sq test
ChiSqResult = chi2_contingency(CrosstabResult)
 
# P-Value is the Probability of H0 being True
# If P-Value&gt;0.05 then only we Accept the assumption(H0)
 
print('The P-Value of the ChiSq Test is:', ChiSqResult[1])
# Out:
# Are you willing to shift to Private Accommodation?  No  Yes
# WIFI Facility
# Average                                             25   32
# Bad                                                 16   15
# Good                                                 8   11
# No WIFI Facility                                    24   52
# The P-Value of the ChiSq Test is: 0.22329019603540903

# %% [markdown]
# The p - value here we got is greater than 0.05 .
#
#  In this case, with a p-value of 0.22329019603540903, it's higher than the typical 0.05 significance level. This suggests that there isn't strong evidence to conclude that the "WIFI Facility" and the willingness to shift to private accommodation are significantly associated.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Checking relationship between Water Facility in Hostel  and SHIFTING TO PRIVATES

# %% [markdown]
# --> Here The specific hypotheses are:
#
# --> H0: There is a relationship between Water Facility in Hostel  and SHIFTING TO PRIVATES
# --> H1: There is no relationship between  Water Facility and SHIFTING TO PRIVATES
#
#
#
# --> P denotes the probability. The different p-values indicate different types of hypothesis interpretations.
#
# --> P <= 0.05 (H0 is accepted)
# --> P>= 0.05 (H1 is accepted)

# %%
# Cross tabulation between Water Facility in Hostel and SHIFTING TO PRIVATE
CrosstabResult=pd.crosstab(index=data['Water Facility in Hostel'],columns=data['Are you willing to shift to Private Accommodation?'])
print(CrosstabResult)

from scipy.stats import chi2_contingency
 
# Performing Chi-sq test
ChiSqResult = chi2_contingency(CrosstabResult)
 
# P-Value is the Probability of H0 being True
# If P-Value&gt;0.05 then only we Accept the assumption(H0)
 
print('The P-Value of the ChiSq Test is:', ChiSqResult[1])
# Out:
# Are you willing to shift to Private Accommodation?  No  Yes
# Water Facility in Hostel
# Average                                             31   65
# Bad                                                  7   15
# Good                                                35   30
# The P-Value of the ChiSq Test is: 0.016661839015847387

# %% [markdown]
# The p - value here we got is not greater than 0.05 .
#
#  In this case, with a p-value of 0.016661839015847387, it's lower than the typical 0.05 significance level. This suggests that there is a  strong evidence to conclude that the "Water Facility in Hostel" and the willingness to shift to private accommodation are significantly associated.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Checking relationship between Transportation Facility in Hostel

# %% [markdown]
# --> Here The specific hypotheses are:
#
# --> H0: There is a relationship between Transportation Facility in Hostel   and SHIFTING TO PRIVATES
# --> H1: There is no relationship between Transportation Facility in Hostel  and SHIFTING TO PRIVATES
#
#
#
# --> P denotes the probability. The different p-values indicate different types of hypothesis interpretations.
#
# --> P <= 0.05 (H0 is accepted)
# --> P>= 0.05 (H1 is accepted)

# %%
# Cross tabulation between Transportation Facility and SHIFTING TO PRIVATE
CrosstabResult=pd.crosstab(index=data['Transportation Facility'],columns=data['Are you willing to shift to Private Accommodation?'])
print(CrosstabResult)

from scipy.stats import chi2_contingency
 
# Performing Chi-sq test
ChiSqResult = chi2_contingency(CrosstabResult)
 
# P-Value is the Probability of H0 being True
# If P-Value&gt;0.05 then only we Accept the assumption(H0)
 
print('The P-Value of the ChiSq Test is:', ChiSqResult[1])
# Out:
# Are you willing to shift to Private Accommodation?  No  Yes
# Transportation Facility
# Any Private Transportation                           4    7
# By Bus                                              12   25
# By Walking                                          57   78
# The P-Value of the ChiSq Test is: 0.5429504292527374

# %% [markdown]
# The p - value here we got is  greater than 0.05 .
#
#  In this case, with a p-value of 0.5429504292527374, it's higher than the typical 0.05 significance level. This suggests that there isn't a  strong evidence to conclude that the "Transportation Facility'" and the willingness to shift to private accommodation are significantly associated.

# %% [markdown]
# ------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Checking relationship between Adjustment issue with Room-mates  and SHIFTING TO PRIVATES

# %% [markdown]
# --> Here The specific hypotheses are:
#
# --> H0: There is no relationship between Water Facility in Hostel  and SHIFTING TO PRIVATES
# --> H1: There is a relationship between gender and getting in trouble at school
#
#
#
# --> P denotes the probability. The different p-values indicate different types of hypothesis interpretations.
#
# --> P <= 0.05 (H0 is accepted)
# --> P>= 0.05 (H1 is accepted)

# %%
# Cross tabulation between Adjustment issue with Room-mates and SHIFTING TO PRIVATE
CrosstabResult=pd.crosstab(index=data['Adjustment issue with Room-mates'],columns=data['Are you willing to shift to Private Accommodation?'])
print(CrosstabResult)

from scipy.stats import chi2_contingency
 
# Performing Chi-sq test
ChiSqResult = chi2_contingency(CrosstabResult)
 
# P-Value is the Probability of H0 being True
# If P-Value&gt;0.05 then only we Accept the assumption(H0)
 
print('The P-Value of the ChiSq Test is:', ChiSqResult[1])
# Out:
# Are you willing to shift to Private Accommodation?  No  Yes
# Adjustment issue with Room-mates
# I'm happy                                           55   79
# No room-mate                                        13    7
# Not able to adjust                                   5   24
# The P-Value of the ChiSq Test is: 0.003123575686952663

# %% [markdown]
# The p - value here we got is  less than 0.05 .
#
#  In this case, with a p-value of 0.003123575686952663, it's lower  than the typical 0.05 significance level. This suggests that there is a  strong evidence to conclude that the "Adjustment issue with Room-mates" and the willingness to shift to private accommodation are significantly associated.

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Checking relationship between STUDENTS' REGULAR FOOD PREFERENCES  and SHIFTING TO PRIVATES

# %% [markdown]
# --> Here The specific hypotheses are:
#
# --> H0: There is a relationship between student's regular food preferances  and SHIFTING TO PRIVATES
# --> H1: There is no relationship between student's regular food preferances  and SHIFTING TO PRIVATES
#
#
# --> P denotes the probability. The different p-values indicate different types of hypothesis interpretations.
#
# --> P <= 0.05 (H0 is accepted)
# --> P>= 0.05 (H1 is accepted)

# %%
# Cross tabulation between Your regular food preference and SHIFTING TO PRIVATE
CrosstabResult=pd.crosstab(index=data['Your regular food preference'],columns=data['Are you willing to shift to Private Accommodation?'])
print(CrosstabResult)

from scipy.stats import chi2_contingency
 
# Performing Chi-sq test
ChiSqResult = chi2_contingency(CrosstabResult)
 
# P-Value is the Probability of H0 being True
# If P-Value&gt;0.05 then only we Accept the assumption(H0)
 
print('The P-Value of the ChiSq Test is:', ChiSqResult[1])
# Out:
# Are you willing to shift to Private Accommodation?  No  Yes
# Your regular food preference
# Home-made as well as outside                        37   60
# Only home-made                                      12    7
# Outside                                             24   43
# The P-Value of the ChiSq Test is: 0.08733946482547951

# %% [markdown]
# The p - value here we got is  greater  than 0.05 .
#
#  In this case, with a p-value of  0.08733946482547951,it's higher  than the typical 0.05 significance level. This suggests that there is not a  strong evidence to conclude that the regular food preferances of students' and the willingness to shift to private accommodation are  significantly associated.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Checking relationship between COPING-UP WITH CHRIST RULES AND REGULATION  and SHIFTING TO PRIVATES

# %% [markdown]
# --> Here The specific hypotheses are:
#
# --> H0: There is no relationship between Coping-up with Christ Rules & Regulation  and SHIFTING TO PRIVATES
# --> H1: There is a relationship between gender and getting in trouble at school
#
#
#
# --> P denotes the probability. The different p-values indicate different types of hypothesis interpretations.
#
# --> P <= 0.05 (H0 is accepted)
# --> P>= 0.05 (H1 is accepted)

# %%
# Cross tabulation between Coping-up with Christ Rules & Regulation and SHIFTING TO PRIVATE
CrosstabResult=pd.crosstab(index=data['Coping-up with Christ Rules & Regulation'],columns=data['Are you willing to shift to Private Accommodation?'])
print(CrosstabResult)

from scipy.stats import chi2_contingency
 
# Performing Chi-sq test
ChiSqResult = chi2_contingency(CrosstabResult)
 
# P-Value is the Probability of H0 being True
# If P-Value&gt;0.05 then only we Accept the assumption(H0)
 
print('The P-Value of the ChiSq Test is:', ChiSqResult[1])
# Out:
# Are you willing to shift to Private Accommodation?  No  Yes
# Coping-up with Christ Rules & Regulation
# Facing difficulties                                 37   68
# Not facing any difficulty                           36   42
# The P-Value of the ChiSq Test is: 0.18068080562048217

# %% [markdown]
# The p - value here we got is  greater than 0.05 .
#
#  In this case, with a p-value of  0.18068080562048217, it's greater   than the typical 0.05 significance level. This suggests that there is not  a  strong evidence to conclude that "Coping-up with Christ Rules & Regulation" and "the willingness to shift to private accommodation" are significantly associated.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# HISTOGRAM :
#
# A Histogram is a variation of a bar chart in which data values are grouped together and put into different classes. This grouping enables you to see how frequently data in each class occur in the dataset.
#
# The histogram graphically shows the following:
#
# --> Frequency of different data points in the dataset.
# --> Location of the center of data.
# --> The spread of dataset.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

sns.histplot(binwidth=0.5, x="WIFI Facility", hue="Are you willing to shift to Private Accommodation?", data=df, stat="count", multiple="stack")
# Out:
# <Axes: xlabel='WIFI Facility', ylabel='Count'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

sns.histplot(binwidth=0.5, x="Water Facility in Hostel", hue="Are you willing to shift to Private Accommodation?", data=df, stat="count", multiple="stack")
# Out:
# <Axes: xlabel='Water Facility in Hostel', ylabel='Count'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

sns.histplot(binwidth=0.5, x="Adjustment issue with Room-mates", hue="Are you willing to shift to Private Accommodation?", data=df, stat="count", multiple="stack")
# Out:
# <Axes: xlabel='Adjustment issue with Room-mates', ylabel='Count'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

sns.histplot(binwidth=0.5, x="Your regular food preference", hue="Are you willing to shift to Private Accommodation?", data=df, stat="count", multiple="stack")
# Out:
# <Axes: xlabel='Your regular food preference', ylabel='Count'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

sns.histplot(binwidth=0.5, x="Coping-up with Christ Rules & Regulation", hue="Are you willing to shift to Private Accommodation?", data=df, stat="count", multiple="stack")
# Out:
# <Axes: xlabel='Coping-up with Christ Rules & Regulation', ylabel='Count'>

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# BARPLOT   :
#
# A bar graph is a graphical representation of data in which we can highlight the category with particular shapes like a rectangle. The length and heights of the bar chart represent the data distributed in the dataset.
#
#  It consists of rectangular bars with variable heights.

# %%
first_dimension = "Select Gender"
horizontal_label = "x label"
second_dimension = "WIFI Facility"

# %%
sns.barplot(x=horizontal_label,
            y=first_dimension,
            hue=second_dimension,
            data=df.groupby([first_dimension, second_dimension]).size().to_frame(horizontal_label).reset_index())
# Out:
# <Axes: xlabel='x label', ylabel='Select Gender'>

# %%
first_dimension = "Select Gender"
horizontal_label = "x label"
second_dimension = "Water Facility in Hostel"

# %%
sns.barplot(x=horizontal_label,
            y=first_dimension,
            hue=second_dimension,
            data=df.groupby([first_dimension, second_dimension]).size().to_frame(horizontal_label).reset_index())
# Out:
# <Axes: xlabel='x label', ylabel='Select Gender'>

# %%
first_dimension = "Select Gender"
horizontal_label = "x label"
second_dimension = "Transportation Facility"

# %%
sns.barplot(x=horizontal_label,
            y=first_dimension,
            hue=second_dimension,
            data=df.groupby([first_dimension, second_dimension]).size().to_frame(horizontal_label).reset_index())
# Out:
# <Axes: xlabel='x label', ylabel='Select Gender'>

# %%
first_dimension = "Select Gender"
horizontal_label = "x label"
second_dimension = "Your regular food preference"

# %%
sns.barplot(x=horizontal_label,
            y=first_dimension,
            hue=second_dimension,
            data=df.groupby([first_dimension, second_dimension]).size().to_frame(horizontal_label).reset_index())
# Out:
# <Axes: xlabel='x label', ylabel='Select Gender'>

# %%
first_dimension = "Select Gender"
horizontal_label = "x label"
second_dimension = "Coping-up with Christ Rules & Regulation"

# %%
sns.barplot(x=horizontal_label,
            y=first_dimension,
            hue=second_dimension,
            data=df.groupby([first_dimension, second_dimension]).size().to_frame(horizontal_label).reset_index())
# Out:
# <Axes: xlabel='x label', ylabel='Select Gender'>

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# CATPLOT  :
#
# This plot represents Figure-level interface for drawing categorical plots onto a FacetGrid. This function provides access to several axes-level functions that show the relationship between a numerical and one or more categorical variables using one of several visual representations

# %%
g = sns.catplot(x="Select Gender",  y="WIFI Facility", hue="Select Gender",col="Hostel type",data=data)

# %%
g = sns.catplot(x="Select Gender",  y="Water Facility in Hostel", hue="Select Gender",col="Hostel type",data=data)

# %%
g = sns.catplot(x="Select Gender",  y="Transportation Facility", hue="Select Gender",col="Hostel type",data=data)

# %%
g = sns.catplot(x="Select Gender",  y="Adjustment issue with Room-mates", hue="Select Gender",col="Hostel type",data=data)

# %%
g = sns.catplot(x="Select Gender",  y="Coping-up with Christ Rules & Regulation", hue="Select Gender",col="Hostel type",data=data)

# %%
g = sns.catplot(x="Select Gender",  y="Your regular food preference", hue="Select Gender",col="Hostel type",data=data)

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
#                                                         *INFERENCE*

# %% [markdown]
# IN THIS PYHTON PROJECT WE WERE INTERESTED TO SEE WHICH FACTORS ARE COMPELLING THE STUDENTS TO SHIFT IN PRIVATES.
# OUR ATTRUBUTES WERE - Water Facility in Hostel                                                  0
# -- > WIFI Facility
# -- > Transportation Facility
# -- > Adjustment issue with Room-mates
# -- > Your regular food preference
# -- > Coping-up with Christ Rules & Regulation
#
# FOR THIS PART WE DID  CHI-SQUARE TESTS TO SEE WETHER THE TWO VARIBLES (EACH ATTRIBUTE AND WILLING TO SHIFT  IN PRIVATES ARE RELATED OR NOT , THAT IS WETHER THERE IS ANY ASSOCIATION BETWEEN THEM OR NOT.)

# %% [markdown]
# AFTER DOING THE CHI- SQUARE TEST WE FOUND THAT -
#
# --> THE ATTRIBUTE " WIFI FACILITY IN HOSTEL" AND " SHIFTING TO PRIVATES" ARE SIGNIFICANTLY RELATED . THAT IS THE SHIFTING INTO PRIVATES IS INFLUENCED BY THE WIFI FACILITY
#
# -->  THE ATTRIBUTE " ADJUSTMENT ISSUES WITH ROOM-MATES" AND " SHIFTING TO PRIVATES" ARE SIGNIFICANTLY RELATED . THAT IS THE SHIFTING INTO PRIVATES IS INFLUENCED BY THE ADJUSTMENT ISSUES WITH ROOM-MATES.
