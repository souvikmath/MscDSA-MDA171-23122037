# %%
pip install numpy
# Out:
# ...
# [notice] A new release of pip is available: 23.1.2 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#                                               0.0/15.8 MB ? eta -:--:--
#                                               0.0/15.8 MB ? eta -:--:--
#                                               0.0/15.8 MB ? eta -:--:--
#                                               0.0/15.8 MB ? eta -:--:--
#                                               0.0/15.8 MB ? eta -:--:--
#                                              0.0/15.8 MB 435.7 kB/s eta 0:00:37
#                                              0.0/15.8 MB 435.7 kB/s eta 0:00:37
#                                              0.0/15.8 MB 435.7 kB/s eta 0:00:37
#                                              0.0/15.8 MB 435.7 kB/s eta 0:00:37
#                                              0.0/15.8 MB 151.3 kB/s eta 0:01:45
#                                              0.0/15.8 MB 151.3 kB/s eta 0:01:45
# ...

# %%
import numpy as np
a= np.array([1,2,3])
print(a)
# Out:
# [1 2 3]

# %%
import numpy as np
b=np.array(([(1.5,2,3),(4,5,6)]),dtype = float)
print(b)
# Out:
# [[1.5 2.  3. ]
#  [4.  5.  6. ]]
