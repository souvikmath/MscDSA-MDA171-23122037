# %%
pip install seaborn
# Out:
# ...
#                                               0.0/294.6 kB ? eta -:--:--
#                                               0.0/294.6 kB ? eta -:--:--
#      -                                        10.2/294.6 kB ? eta -:--:--
#      ----                                    30.7/294.6 kB 1.3 MB/s eta 0:00:01
#      ----                                    30.7/294.6 kB 1.3 MB/s eta 0:00:01
#      ----                                    30.7/294.6 kB 1.3 MB/s eta 0:00:01
#      ----------                            81.9/294.6 kB 416.7 kB/s eta 0:00:01
#      ----------                            81.9/294.6 kB 416.7 kB/s eta 0:00:01
#      -------------                        112.6/294.6 kB 385.0 kB/s eta 0:00:01
#      ---------------                      122.9/294.6 kB 399.4 kB/s eta 0:00:01
#      -----------------                    143.4/294.6 kB 387.0 kB/s eta 0:00:01
#      --------------------                 163.8/294.6 kB 392.8 kB/s eta 0:00:01
# ...

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
df=pd.read_csv("shopping_trends_updated.csv")

# %%
sns.catplot(data=df, x="Size", y="Color")

# %%
#Task 
#load a csv ,set new col names
#load a datasets, set one column as index column
#split your data into multiple files with respect to rows and column load the different files and merge it to one file.

# %% [markdown]
#  Write a python program there will be a functionname create data set,a dictionary,filename save the file ,number of rows as arguments,the dictionary having the following structure :
# {"col name":[domain of values]
# .........
# ....6 column names.....
#   ....... }
# your function will select random values from each of the domains and create a row for you,number of rows that has to be created is a the parameter,with the require number of rows,load the dataset using pandas and display basic detalis,

# %%
import pandas as pd

import random

def Create_dataset(Data_dict,file_name,number_rows):

    
    dict={
        "Name":["Souvik","Naveen","Jeffin","Dhrubil","Siddhart"],
        "Age":[22,23,24,20,21,],
        "State":["WB","KR","UK","GR"],

    }

Create_dataset(dict,"data.csv",50)
